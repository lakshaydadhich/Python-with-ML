# %%
import pandas as pd
training=pd.read_csv('/content/Train-1617360447408-1660719685476 (1).csv')
testing=pd.read_csv('/content/test-1617360461595-1660719701431 (1).csv')

# %%
training.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-868cc223d2c3> in <cell line: 1>()
# ----> 1 training.info()
#
# NameError: name 'training' is not defined

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16647 entries, 0 to 16646
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               16647 non-null  int64
#  1   encounter_id        16647 non-null  int64
#  2   patient_id          16647 non-null  int64
#  3   race                16647 non-null  object
#  4   gender              16647 non-null  object
#  5   age                 16647 non-null  object
#  6   weight              16647 non-null  object
#  7   time_in_hospital    16647 non-null  int64
#  8   medical_specialty   16647 non-null  object
#  9   num_lab_procedures  16647 non-null  int64
#  10  num_procedures      16647 non-null  int64
#  11  num_medications     16647 non-null  int64
#  12  number_outpatient   16647 non-null  int64
#  13  number_emergency    16647 non-null  int64
#  14  number_inpatient    16647 non-null  int64
# ...

# %%
training.describe()
# Out:
#                index  encounter_id    patient_id  time_in_hospital  \
# count   66587.000000  6.658700e+04  6.658700e+04      66587.000000
# mean    50903.474282  1.653153e+08  5.422970e+07          4.397510
# std     29480.255515  1.030035e+08  3.878819e+07          2.980995
# min         0.000000  1.573800e+04  1.350000e+02          1.000000
# 25%     25166.500000  8.440328e+07  2.338646e+07          2.000000
# 50%     51129.000000  1.528504e+08  4.526103e+07          4.000000
# 75%     76380.000000  2.305049e+08  8.727185e+07          6.000000
# max    101765.000000  4.438672e+08  1.893494e+08         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count        66587.000000    66587.000000     66587.000000       66587.000000
# mean            43.115533        1.331521        16.028744           0.365672
# std             19.630417        1.705746         8.125304           1.221861
# ...

# %%
testing.describe()
# Out:
#                index  encounter_id    patient_id  time_in_hospital  \
# count   16647.000000  1.664700e+04  1.664700e+04      16647.000000
# mean    50466.520154  1.639414e+08  5.417128e+07          4.366132
# std     29480.114748  1.030296e+08  3.884859e+07          2.950424
# min        26.000000  2.363160e+05  1.350000e+02          1.000000
# 25%     24566.500000  8.313437e+07  2.333162e+07          2.000000
# 50%     50707.000000  1.520358e+08  4.539897e+07          4.000000
# 75%     75869.500000  2.282969e+08  8.764641e+07          6.000000
# max    101759.000000  4.438428e+08  1.894451e+08         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count        16647.000000    16647.000000     16647.000000       16647.000000
# mean            43.055866        1.344206        15.954646           0.367093
# std             19.623995        1.706926         8.093555           1.265388
# ...

# %%
training.shape
# Out:
# (66587, 49)

# %%
testing.shape
# Out:
# (16647, 48)

# %%
# evaluting null values in datasets
print(training.isnull().sum())
print(testing.isnull().sum())
# Out:
# index                     0
# encounter_id              0
# patient_id                0
# race                      0
# gender                    0
# age                       0
# weight                    0
# time_in_hospital          0
# medical_specialty         0
# num_lab_procedures        0
# num_procedures            0
# num_medications           0
# number_outpatient         0
# number_emergency          0
# number_inpatient          0
# diag_1                    0
# diag_2                    0
# diag_3                    0
# diag_4                    0
# diag_5                    0
# number_diagnoses          0
# X1                    63104
# X2                    55451
# X3                        0
# X4                        0
# X5                        0
# X6                        0
# X7                        0
# X8                        0
# X9                        0
# X10                       0
# X11                       0
# X12                       0
# ...

# %%
# visualize the target variable
import seaborn as sns
sns.countplot(x='readmitted',data=training)
# Out:
# <Axes: xlabel='readmitted', ylabel='count'>

# %%
training.head(10)
# Out:
#    index  encounter_id  patient_id             race  gender      age weight  \
# 0  69375     197029140    51521940         Hispanic    Male  [80-90)      ?
# 1  57272     163571946    92631357        Caucasian    Male  [60-70)      ?
# 2  82347     256497366    30023982        Caucasian  Female  [50-60)      ?
# 3  89608     289891212    93606021  AfricanAmerican  Female  [70-80)      ?
# 4  24091      81873900    23464296        Caucasian    Male  [70-80)      ?
# 5  11756      48391902    29635362  AfricanAmerican    Male  [40-50)      ?
# 6  42376     130669056    35476317        Caucasian    Male  [70-80)      ?
# 7  91744     313193054   171347630        Caucasian  Female  [40-50)      ?
# 8  27014      88645302    20811105        Caucasian  Female  [70-80)      ?
# 9  95964     369018230   115650671        Caucasian    Male  [70-80)      ?
#
#    time_in_hospital       medical_specialty  num_lab_procedures  ...  X19  \
# ...

# %%
# Handling Age column in Training data
median_mapping = {
    '[80-90)': 85,
    '[60-70)': 65,
    '[50-60)': 55,
    '[70-80)': 75,
    '[40-50)': 45,
    '[30-40)':35,
    '[90-100)':95,
    '[20-30)':25,
    '[0-10)':5,
    '[10-20)':15,



}
training['age']=training['age'].replace(median_mapping)
training
# Out:
# <ipython-input-151-b53f81ad6f10>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   training['age']=training['age'].replace(median_mapping)
#        index  encounter_id  patient_id             race  gender  age weight  \
# 0      69375     197029140    51521940         Hispanic    Male   85      ?
# 1      57272     163571946    92631357        Caucasian    Male   65      ?
# 2      82347     256497366    30023982        Caucasian  Female   55      ?
# 3      89608     289891212    93606021  AfricanAmerican  Female   75      ?
# 4      24091      81873900    23464296        Caucasian    Male   75      ?
# ...      ...           ...         ...              ...     ...  ...    ...
# ...

# %%
# handling weight column in training data
median_mapping1 = {
    '[0-25)': 13,
    '[25-50)': 38,
    '[50-75)': 63,
    '[75-100)': 88,
    '[100-125)': 113,
    '[125-150)': 138,
    '[150-175)': 163,
    '[175-200)': 188,
}

# Replace values in the weight column using the mapping
training['weight'] = training['weight'].replace(median_mapping1)

# %%
# handling missing data in weight column in training data
training['weight'] = pd.to_numeric(training['weight'], errors='coerce')

training['weight'] = training['weight'].fillna(training['weight'].mean())

# %%
training.head(10)
# Out:
#    index  encounter_id  patient_id             race  gender  age    weight  \
# 0  69375     197029140    51521940         Hispanic    Male   85  87.18976
# 1  57272     163571946    92631357        Caucasian    Male   65  87.18976
# 2  82347     256497366    30023982        Caucasian  Female   55  87.18976
# 3  89608     289891212    93606021  AfricanAmerican  Female   75  87.18976
# 4  24091      81873900    23464296        Caucasian    Male   75  87.18976
# 5  11756      48391902    29635362  AfricanAmerican    Male   45  87.18976
# 6  42376     130669056    35476317        Caucasian    Male   75  87.18976
# 7  91744     313193054   171347630        Caucasian  Female   45  87.18976
# 8  27014      88645302    20811105        Caucasian  Female   75  87.18976
# 9  95964     369018230   115650671        Caucasian    Male   75  87.18976
#
#    time_in_hospital       medical_specialty  num_lab_procedures  ...  X19  \
# ...

# %%
# handling Mediacal_specility column in training data


from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
training['medical_specialty']=le.fit_transform(training['medical_specialty'])
training['diabetesMed']=le.fit_transform(training['diabetesMed'])  # yes-1,no-0
training['gender']=le.fit_transform(training['gender'])  # Male-1,Female-0
training['patient_id	']=le.fit_transform(training['patient_id'])
training['patient_id	']=le.fit_transform(training['patient_id'])

# %%
training.head(5)
# Out:
#    index  encounter_id  patient_id             race  gender  age    weight  \
# 0  69375     197029140    51521940         Hispanic       1   85  87.18976
# 1  57272     163571946    92631357        Caucasian       1   65  87.18976
# 2  82347     256497366    30023982        Caucasian       0   55  87.18976
# 3  89608     289891212    93606021  AfricanAmerican       0   75  87.18976
# 4  24091      81873900    23464296        Caucasian       1   75  87.18976
#
#    time_in_hospital  medical_specialty  num_lab_procedures  ...   X20  X21  \
# 0                 4                  8                  39  ...    No   No
# 1                 3                  8                  34  ...    No   No
# 2                 6                 19                  50  ...  Down   No
# 3                 5                  0                  63  ...  Down   No
# 4                 9                 43                  17  ...    No   No
#
# ...

# %%
# handling Age column in testing data
median_mapping2 = {
    '[80-90)': 85,
    '[60-70)': 65,
    '[50-60)': 55,
    '[70-80)': 75,
    '[40-50)': 45,
    '[30-40)':35,
    '[90-100)':95,
    '[20-30)':25,
    '[0-10)':5,
    '[10-20)':15,



}
testing['age']=testing['age'].replace(median_mapping)
testing
# Out:
# <ipython-input-157-cb15f8c64005>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   testing['age']=testing['age'].replace(median_mapping)
#        index  encounter_id  patient_id             race  gender  age weight  \
# 0      11128      46325466     3928383        Caucasian  Female   75      ?
# 1      79758     245219616    60926103        Caucasian    Male   65      ?
# 2      52497     155321232    25234848  AfricanAmerican    Male   75      ?
# 3      64504     179491944    86935374        Caucasian  Female   75      ?
# 4        987       7425954     2486826  AfricanAmerican  Female   55      ?
# ...      ...           ...         ...              ...     ...  ...    ...
# 16642  69643     198316824    71780013        Caucasian    Male   75      ?
# ...

# %%
# handling weight column in testing data
median_mapping2 = {
    '[0-25)': 13,
    '[25-50)': 38,
    '[50-75)': 63,
    '[75-100)': 88,
    '[100-125)': 113,
    '[125-150)': 138,
    '[150-175)': 163,
    '[175-200)': 188,
}

# Replace values in the weight column using the mapping
testing['weight'] = testing['weight'].replace(median_mapping2)

# %%
# handling missing data in weight column in testing data
testing['weight'] = pd.to_numeric(testing['weight'], errors='coerce')

testing['weight'] = testing['weight'].fillna(testing['weight'].mean())

# %%
testing.head(5)
# Out:
#    index  encounter_id  patient_id             race  gender  age    weight  \
# 0  11128      46325466     3928383        Caucasian  Female   75  87.12037
# 1  79758     245219616    60926103        Caucasian    Male   65  87.12037
# 2  52497     155321232    25234848  AfricanAmerican    Male   75  87.12037
# 3  64504     179491944    86935374        Caucasian  Female   75  87.12037
# 4    987       7425954     2486826  AfricanAmerican  Female   55  87.12037
#
#    time_in_hospital medical_specialty  num_lab_procedures  ...  X18  X19  \
# 0                 3                 ?                  45  ...   No   No
# 1                 2                 ?                  10  ...   No   No
# 2                11  InternalMedicine                  41  ...   No   No
# 3                 1  InternalMedicine                  71  ...   No   No
# 4                 7  InternalMedicine                  59  ...   No   No
#
#       X20  X21  X22 X23 X24 X25 change  diabetesMed
# ...

# %%
# handling Mediacal_specility column in testing data


from sklearn.preprocessing import LabelEncoder
le2=LabelEncoder()
testing['medical_specialty']=le2.fit_transform(testing['medical_specialty'])
testing['diabetesMed']=le2.fit_transform(testing['diabetesMed'])  # yes-1,no-0
testing['gender']=le2.fit_transform(testing['gender'])  # Male-1,Female-0
#training['encounter_id	']=le.fit_transform(training['encounter_id	'])
testing['patient_id	']=le2.fit_transform(testing['patient_id'])
testing['patient_id	']=le2.fit_transform(testing['patient_id'])

# %%
testing.head(5)
# Out:
#    index  encounter_id  patient_id             race  gender  age    weight  \
# 0  11128      46325466     3928383        Caucasian       0   75  87.12037
# 1  79758     245219616    60926103        Caucasian       1   65  87.12037
# 2  52497     155321232    25234848  AfricanAmerican       1   75  87.12037
# 3  64504     179491944    86935374        Caucasian       0   75  87.12037
# 4    987       7425954     2486826  AfricanAmerican       0   55  87.12037
#
#    time_in_hospital  medical_specialty  num_lab_procedures  ...  X19     X20  \
# 0                 3                  0                  45  ...   No      No
# 1                 2                  0                  10  ...   No      No
# 2                11                 14                  41  ...   No  Steady
# 3                 1                 14                  71  ...   No      No
# 4                 7                 14                  59  ...   No  Steady
#
# ...

# %%
# dropping column in training

training.drop(columns=['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
                       'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
                       'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'race'], inplace=True)

training.head(5)
training .drop(columns=['diag_1','diag_2','diag_3','diag_4','diag_5'],inplace=True)
training.drop(columns=['index'],inplace=True)

# %%
testing.columns
# Out:
# Index(['index', 'encounter_id', 'patient_id', 'race', 'gender', 'age',
#        'weight', 'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'diag_4', 'diag_5', 'number_diagnoses', 'X1', 'X2', 'X3', 'X4', 'X5',
#        'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16',
#        'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'change',
#        'diabetesMed', 'patient_id\t'],
#       dtype='object')

# %%
# dropping columns in testing

testing.drop(columns=['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
                       'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
                       'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'race'], inplace=True)

testing.head(5)
# Out:
#    index  encounter_id  patient_id  gender  age    weight  time_in_hospital  \
# 0  11128      46325466     3928383       0   75  87.12037                 3
# 1  79758     245219616    60926103       1   65  87.12037                 2
# 2  52497     155321232    25234848       1   75  87.12037                11
# 3  64504     179491944    86935374       0   75  87.12037                 1
# 4    987       7425954     2486826       0   55  87.12037                 7
#
#    medical_specialty  num_lab_procedures  num_procedures  ...  \
# 0                  0                  45               3  ...
# 1                  0                  10               1  ...
# 2                 14                  41               1  ...
# 3                 14                  71               2  ...
# 4                 14                  59               2  ...
#
#    number_inpatient  diag_1  diag_2  diag_3 diag_4     diag_5  \
# 0                 1     786     414     410    410  63.103503
# ...

# %%
testing .drop(columns=['diag_1','diag_2','diag_3','diag_4','diag_5'],inplace=True)
testing.drop(columns=['index'],inplace=True)

# %%
testing.columns
# Out:
# Index(['encounter_id', 'patient_id', 'gender', 'age', 'weight',
#        'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'number_diagnoses', 'change',
#        'diabetesMed', 'patient_id\t'],
#       dtype='object')

# %%
# evaluting null values in datasets
print(training.isnull().sum())
print(testing.isnull().sum())
# Out:
# encounter_id          0
# patient_id            0
# gender                0
# age                   0
# weight                0
# time_in_hospital      0
# medical_specialty     0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_outpatient     0
# number_emergency      0
# number_inpatient      0
# number_diagnoses      0
# change                0
# diabetesMed           0
# readmitted            0
# patient_id\t          0
# dtype: int64
# encounter_id          0
# patient_id            0
# gender                0
# age                   0
# weight                0
# time_in_hospital      0
# medical_specialty     0
# num_lab_procedures    0
# num_procedures        0
# num_medications       0
# number_outpatient     0
# number_emergency      0
# number_inpatient      0
# number_diagnoses      0
# change                0
# diabetesMed           0
# patient_id\t          0
# dtype: int64

# %%
training.columns
# Out:
# Index(['encounter_id', 'patient_id', 'gender', 'age', 'weight',
#        'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'number_diagnoses', 'change',
#        'diabetesMed', 'readmitted', 'patient_id\t'],
#       dtype='object')

# %%
training.drop(columns=['change'],inplace=True)

# %%
testing.drop(columns=['change'],inplace=True)

# %%
training.head(10)
# Out:
#    encounter_id  patient_id  gender  age    weight  time_in_hospital  \
# 0     197029140    51521940       1   85  87.18976                 4
# 1     163571946    92631357       1   65  87.18976                 3
# 2     256497366    30023982       0   55  87.18976                 6
# 3     289891212    93606021       0   75  87.18976                 5
# 4      81873900    23464296       1   75  87.18976                 9
# 5      48391902    29635362       1   45  87.18976                 3
# 6     130669056    35476317       1   75  87.18976                 9
# 7     313193054   171347630       0   45  87.18976                 4
# 8      88645302    20811105       0   75  87.18976                13
# 9     369018230   115650671       1   75  87.18976                 3
#
#    medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# 0                  8                  39               1                9
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
x_train_full=training.drop(columns=['readmitted'])
y_train_full=training['readmitted']

model=RandomForestClassifier(random_state=42)
model.fit(x_train_full,y_train_full)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# predicting
X_test = testing.drop(columns=['readmitted'], errors='ignore')

test_predictions = model.predict(X_test)

print(test_predictions)
# Out:
# [1 0 0 ... 1 0 0]

# %%
#  Evaluate the Model on the Validation Set



from sklearn.model_selection import train_test_split

# Split the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_val_predictions = model.predict(X_val)

accuracy = accuracy_score(y_val, y_val_predictions)
print(f"Accuracy: {accuracy:.2f}")

print("Classification Report:")
print(classification_report(y_val, y_val_predictions))

print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_predictions))
# Out:
# Accuracy: 0.79
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      7195
#            1       0.79      0.74      0.77      6123
#
#     accuracy                           0.79     13318
#    macro avg       0.79      0.79      0.79     13318
# weighted avg       0.79      0.79      0.79     13318
#
# Confusion Matrix:
# [[5980 1215]
#  [1568 4555]]

# %%
# correlation matrix

import matplotlib.pyplot as plt
import seaborn as sns
# Compute the correlation matrix for the training dataset
correlation_matrix = training.corr()
# Plot the heatmap
plt.figure(figsize=(16, 10))  # Adjust the figure size for better readability
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Visualize the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_val, y_val_predictions), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
